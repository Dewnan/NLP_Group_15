# %% [markdown]
# # Notebook 2: Exploratory Data Analysis (EDA)
#
# ## Objective
# This notebook performs Exploratory Data Analysis (EDA) on the Fake News Detection dataset.
#
# ### Member
# Pesara (CIT-24-01-0258)
#
# ### Machine Learning Model
# Support Vector Machine (SVM)
#
# ### Deep Learning Model
# Long Short-Term Memory (LSTM)

# %%
import pandas as pd
import matplotlib.pyplot as plt

from wordcloud import WordCloud

# %%
news = pd.read_csv("../data/processed/clean_news.csv")

# %%
print("Rows and Columns")
news.shape
# Out:
# Rows and Columns
# (44689, 6)

# %%
news.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 44689 entries, 0 to 44688
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   title       44689 non-null  str
#  1   text        44689 non-null  str
#  2   label       44689 non-null  int64
#  3   content     44680 non-null  str
#  4   tokens      44689 non-null  str
#  5   clean_text  44680 non-null  str
# dtypes: int64(1), str(5)
# memory usage: 398.5 MB

# %%
news.isnull().sum()
# Out:
# title         0
# text          0
# label         0
# content       9
# tokens        0
# clean_text    9
# dtype: int64

# %%
news["label"].value_counts()
# Out:
# label
# 0    23478
# 1    21211
# Name: count, dtype: int64

# %%
news["label"].value_counts().plot(
    kind="bar",
    figsize=(6,4)
)

plt.title("Fake vs Real News")
plt.xlabel("Label")
plt.ylabel("Number of Articles")

plt.xticks([0,1],["Fake","Real"])

plt.show()

# %%
news["length"] = news["text"].apply(len)

news["length"].describe()
# Out:
# count    44689.000000
# mean      2467.098682
# std       2173.612347
# min          1.000000
# 25%       1232.000000
# 50%       2185.000000
# 75%       3101.000000
# max      51794.000000
# Name: length, dtype: float64

# %%
plt.figure(figsize=(8,5))

plt.hist(news["length"], bins=40)

plt.title("Article Length Distribution")

plt.xlabel("Characters")

plt.ylabel("Frequency")

plt.show()

# %%
text = " ".join(news["text"].astype(str))

wordcloud = WordCloud(
    width=800,
    height=400,
    background_color="white"
).generate(text)

plt.figure(figsize=(12,6))

plt.imshow(wordcloud)

plt.axis("off")

plt.title("Most Frequent Words")

plt.show()

# %%
news.head()
# Out:
#                                                title  \
# 0  WOW! LEFTIST LIBRARIAN REJECTS Shipment Of Chi...
# 1  Kenya opposition leader calls for calm in slum...
# 2  Egypt rejects U.S. decision to move its embass...
# 3  (AUDIO)NATION OF ISLAM LEADER FARRAKHAN: “WE W...
# 4   Trump Rally Nearly Turns Into A Full-Blown Ra...
#
#                                                 text  label  \
# 0  A school librarian in Cambridge, Massachusetts...      0
# 1  NAIROBI (Reuters) - Kenyan opposition leader R...      1
# 2  CAIRO (Reuters) - Egypt rejected the U.S. deci...      1
# 3  After a recent speech given by Minister Louis ...      0
# 4  Tensions ran high outside of a campaign rally ...      0
#
#                                              content  \
# 0  wow leftist librarian rejects shipment of chil...
# 1  kenya opposition leader calls for calm in slum...
# 2  egypt rejects us decision to move its embassy ...
# 3  audionation of islam leader farrakhan “we will...
# ...

# %% [markdown]
# # Insights
#
# 1. The dataset contains both fake and real news articles.
#
# 2. The classes are approximately balanced.
#
# 3. Most articles contain long text suitable for NLP tasks.
#
# 4. No significant missing values were observed.
#
# 5. Word frequency analysis shows commonly occurring news-related words.
#
# 6. The dataset is suitable for Fake News Detection using Machine Learning and Deep Learning models.
